# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense
from tensorflow.keras import Sequential

# %% [markdown]
# y = sin(2x) + cos(x)

# %%
# data 생성

x = np.arange(0, 100, 0.1)
y = 0.5*np.sin(2*x) - np.cos(x/2.0)

seq_data = y.reshape(-1,1)

print(seq_data.shape)
print(seq_data[:5])
# Out:
# (1000, 1)
# [[-1.        ]
#  [-0.89941559]
#  [-0.80029499]
#  [-0.70644984]
#  [-0.62138853]]

# %%
plt.grid()
plt.title('sin(2x)+cos(x)')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.plot(seq_data)

plt.show()

# %%
def seq2dataset(seq, window, horizon):
    X = []
    Y = []

    for i in range(len(seq)-(window+horizon)+1):
        x = seq[i:(i+window)]
        y = (seq[i+window+horizon-1])
        X.append(x)
        Y.append(y)

    return np.array(X), np.array(Y)

# %%
w = 20  # window size
h = 1  # horizon factor

X, Y = seq2dataset(seq_data, w, h)

print(X.shape, Y.shape)
# Out:
# (980, 20, 1) (980, 1)

# %%
split_ratio = 0.8
split = int(split_ratio*len(X))

x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (784, 20, 1) (784, 1) (196, 20, 1) (196, 1)

# %%
model = Sequential()

#model.add(SimpleRNN(units=128, activation='tanh',input_shape=x_train[0].shape))
model.add(SimpleRNN(units=128, activation='tanh',input_shape=(20,1)))
model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 128)               16640
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
from datetime import datetime
start_time = datetime.now()
hist = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))
end_time = datetime.now()
print('Elapsed Time => ', end_time-start_time)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 15ms/step - loss: 0.1354 - mae: 0.2456 - val_loss: 0.0129 - val_mae: 0.0950
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0063 - mae: 0.0640 - val_loss: 0.0030 - val_mae: 0.0466
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0023 - mae: 0.0367 - val_loss: 0.0013 - val_mae: 0.0246
# Epoch 4/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0013 - mae: 0.0280 - val_loss: 9.1551e-04 - val_mae: 0.0240
# Epoch 5/100
# 25/25 [==============================] - 0s 4ms/step - loss: 7.0528e-04 - mae: 0.0205 - val_loss: 5.0309e-04 - val_mae: 0.0167
# Epoch 6/100
# 25/25 [==============================] - 0s 4ms/step - loss: 4.4350e-04 - mae: 0.0156 - val_loss: 3.2885e-04 - val_mae: 0.0135
# Epoch 7/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.9803e-04 - mae: 0.0128 - val_loss: 1.9740e-04 - val_mae: 0.0100
# Epoch 8/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.6374e-04 - mae: 0.0126 - val_loss: 1.9978e-04 - val_mae: 0.0105
# Epoch 9/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.9623e-04 - mae: 0.0110 - val_loss: 1.2843e-04 - val_mae: 0.0086
# Epoch 10/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3955e-04 - mae: 0.0093 - val_loss: 9.3231e-05 - val_mae: 0.0072
# Epoch 11/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.1121e-04 - mae: 0.0083 - val_loss: 8.7649e-05 - val_mae: 0.0075
# Epoch 12/100
# 25/25 [==============================] - 0s 4ms/step - loss: 9.6338e-05 - mae: 0.0079 - val_loss: 6.6707e-05 - val_mae: 0.0065
# Epoch 13/100
# 25/25 [==============================] - 0s 4ms/step - loss: 6.6256e-05 - mae: 0.0066 - val_loss: 4.9277e-05 - val_mae: 0.0058
# Epoch 14/100
# 25/25 [==============================] - 0s 4ms/step - loss: 6.2704e-05 - mae: 0.0063 - val_loss: 4.4343e-05 - val_mae: 0.0054
# Epoch 15/100
# 25/25 [==============================] - 0s 4ms/step - loss: 5.2706e-05 - mae: 0.0059 - val_loss: 3.2012e-05 - val_mae: 0.0046
# Epoch 16/100
# 25/25 [==============================] - 0s 4ms/step - loss: 3.9907e-05 - mae: 0.0051 - val_loss: 6.2949e-05 - val_mae: 0.0068
# Epoch 17/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0773e-04 - mae: 0.0083 - val_loss: 1.5643e-04 - val_mae: 0.0108
# Epoch 18/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.0702e-04 - mae: 0.0117 - val_loss: 9.3153e-04 - val_mae: 0.0267
# Epoch 19/100
# 25/25 [==============================] - 0s 4ms/step - loss: 3.4797e-04 - mae: 0.0154 - val_loss: 2.3075e-04 - val_mae: 0.0116
# Epoch 20/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.4748e-04 - mae: 0.0127 - val_loss: 5.1322e-05 - val_mae: 0.0058
# Epoch 21/100
# 25/25 [==============================] - 0s 4ms/step - loss: 7.0194e-05 - mae: 0.0068 - val_loss: 1.2770e-04 - val_mae: 0.0096
# Epoch 22/100
# 25/25 [==============================] - 0s 4ms/step - loss: 6
100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.7468e-05 - mae: 0.0042 - val_loss: 5.7529e-05 - val_mae: 0.0066
# Epoch 93/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.8243e-05 - mae: 0.0044 - val_loss: 7.0802e-06 - val_mae: 0.0021
# Epoch 94/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.1579e-05 - mae: 0.0027 - val_loss: 5.6017e-05 - val_mae: 0.0060
# Epoch 95/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.0048e-05 - mae: 0.0035 - val_loss: 2.4854e-05 - val_mae: 0.0041
# Epoch 96/100
# 25/25 [==============================] - 0s 4ms/step - loss: 6.2541e-05 - mae: 0.0064 - val_loss: 1.8025e-05 - val_mae: 0.0036
# Epoch 97/100
# 25/25 [==============================] - 0s 4ms/step - loss: 5.3142e-05 - mae: 0.0060 - val_loss: 1.4952e-04 - val_mae: 0.0107
# Epoch 98/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4518e-04 - mae: 0.0097 - val_loss: 4.2009e-04 - val_mae: 0.0171
# Epoch 99/100
# 25/25 [==============================] - 0s 4ms/step - loss: 5.0112e-04 - mae: 0.0181 - val_loss: 5.8069e-04 - val_mae: 0.0188
# Epoch 100/100
# 25/25 [==============================] - 0s 4ms/step - loss: 5.7714e-04 - mae: 0.0188 - val_loss: 2.7306e-04 - val_mae: 0.0136
# Elapsed Time =>  0:00:11.813517

# %%
plt.title('Loss Trend')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend(loc='best')
plt.show()

# %%
pred = model.predict(x_test)
print(pred.shape)
# Out:
# 7/7 [==============================] - 0s 1ms/step
# (196, 1)

# %%
rand_idx = np.random.randint(0, len(y_test), size=5)
print('random idx = ',rand_idx, '\n')
print('pred  = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])
# Out:
# random idx =  [145 182 135 123  32]
#
# pred  =  [ 1.4180568  -0.2392776   0.67576224  0.7061245   0.27171037]
# label =  [ 1.42966394 -0.23920114  0.6645118   0.69218882  0.25367797]

# %%
plt.plot(y_test, label='label')
plt.plot(pred, label='prediction')
plt.grid()
plt.legend(loc='best')
plt.show()

# %% [markdown]
# y = 0.5*sin(2x) - cos(x/2)

# %%
# data 생성

x = np.arange(0, 100, 0.1)
y = 0.5*np.sin(2*x) - np.cos(x/2.0)

seq_data = y.reshape(-1,1)

print(seq_data.shape)
print(seq_data[:5])
# Out:
# (1000, 1)
# [[-1.        ]
#  [-0.89941559]
#  [-0.80029499]
#  [-0.70644984]
#  [-0.62138853]]

# %%
plt.grid()
plt.title('0.5*sin(2x)-cos(x/2)')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.plot(seq_data)

plt.show()

# %%
w = 20  # window size
h = 1  # horizon factor

X, Y = seq2dataset(seq_data, w, h)

print(X.shape, Y.shape)
# Out:
# (980, 20, 1) (980, 1)

# %%
split_ratio = 0.8

split = int(split_ratio*len(X))

x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (784, 20, 1) (784, 1) (196, 20, 1) (196, 1)

# %%
model = Sequential()

model.add(SimpleRNN(units=128, activation='tanh', input_shape=x_train[0].shape))

model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 128)               16640
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
from datetime import datetime

start_time = datetime.now()

hist = model.fit(x_train, y_train, 
                 epochs=100, 
                 validation_data=(x_test, y_test))

end_time = datetime.now()

print('Elapsed Time => ', end_time-start_time)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 10ms/step - loss: 0.0582 - mae: 0.1825 - val_loss: 0.0111 - val_mae: 0.0929
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0056 - mae: 0.0612 - val_loss: 0.0020 - val_mae: 0.0377
# Epoch 3/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0017 - mae: 0.0337 - val_loss: 0.0012 - val_mae: 0.0273
# Epoch 4/100
# 25/25 [==============================] - 0s 4ms/step - loss: 7.6987e-04 - mae: 0.0226 - val_loss: 5.6532e-04 - val_mae: 0.0196
# Epoch 5/100
# 25/25 [==============================] - 0s 4ms/step - loss: 4.7418e-04 - mae: 0.0173 - val_loss: 3.8456e-04 - val_mae: 0.0164
# Epoch 6/100
# 25/25 [==============================] - 0s 4ms/step - loss: 3.2140e-04 - mae: 0.0143 - val_loss: 2.4570e-04 - val_mae: 0.0128
# Epoch 7/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.5163e-04 - mae: 0.0124 - val_loss: 2.5084e-04 - val_mae: 0.0126
# Epoch 8/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.
100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3176e-05 - mae: 0.0028 - val_loss: 1.3662e-05 - val_mae: 0.0030
# Epoch 78/100
# 25/25 [==============================] - 0s 4ms/step - loss: 7.7937e-06 - mae: 0.0022 - val_loss: 8.1374e-06 - val_mae: 0.0023
# Epoch 79/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3951e-05 - mae: 0.0029 - val_loss: 1.3716e-05 - val_mae: 0.0030
# Epoch 80/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.6662e-05 - mae: 0.0042 - val_loss: 1.1171e-05 - val_mae: 0.0028
# Epoch 81/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4606e-05 - mae: 0.0031 - val_loss: 3.6078e-05 - val_mae: 0.0049
# Epoch 82/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0377e-05 - mae: 0.0026 - val_loss: 6.9207e-06 - val_mae: 0.0021
# Epoch 83/100
# 25/25 [==============================] - 0s 4ms/step - loss: 6.6665e-06 - mae: 0.0021 - val_loss: 1.1165e-05 - val_mae: 0.0029
# Epoch 84/100
# 25/25 [==============================] - 0s 4ms/step - loss: 8.4053e-06 - mae: 0.0023 - val_loss: 9.0392e-06 - val_mae: 0.0025
# Epoch 85/100
# 25/25 [==============================] - 0s 4ms/step - loss: 3.1367e-05 - mae: 0.0044 - val_loss: 1.1688e-04 - val_mae: 0.0094
# Epoch 86/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.2049e-04 - mae: 0.0088 - val_loss: 1.5496e-04 - val_mae: 0.0109
# Epoch 87/100
# 25/25 [==============================] - 0s 4ms/step - loss: 9.9392e-05 - mae: 0.0082 - val_loss: 2.0315e-05 - val_mae: 0.0039
# Epoch 88/100
# 25/25 [==============================] - 0s 4ms/step - loss: 6.3352e-05 - mae: 0.0065 - val_loss: 3.9194e-05 - val_mae: 0.0055
# Epoch 89/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.0596e-05 - mae: 0.0036 - val_loss: 1.0359e-05 - val_mae: 0.0027
# Epoch 90/100
# 25/25 [==============================] - 0s 4ms/step - loss: 7.1673e-06 - mae: 0.0021 - val_loss: 8.6313e-06 - val_mae: 0.0025
# Epoch 91/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.4145e-05 - mae: 0.0030 - val_loss: 1.0202e-05 - val_mae: 0.0026
# Epoch 92/100
# 25/25 [==============================] - 0s 4ms/step - loss: 1.9686e-05 - mae: 0.0036 - val_loss: 1.9190e-05 - val_mae: 0.0036
# Epoch 93/100
# 25/25 [==============================] - 0s 4ms/step - loss: 3.5005e-05 - mae: 0.0045 - val_loss: 2.0616e-04 - val_mae: 0.0129
# Epoch 94/100
# 25/25 [==============================] - 0s 4ms/step - loss: 8.0687e-05 - mae: 0.0070 - val_loss: 3.4289e-05 - val_mae: 0.0046
# Epoch 95/100
# 25/25 [==============================] - 0s 4ms/step - loss: 8.1681e-05 - mae: 0.0072 - val_loss: 3.9694e-04 - val_mae: 0.0174
# Epoch 96/100
# 25/25 [==============================] - 0s 5ms/step - loss: 2.7183e-04 - mae: 0.0131 - val_loss: 3.8292e-04 - val_mae: 0.0160
# Epoch 97/100
# 25/25 [==============================] - 0s 4ms/step - loss: 3.6029e-04 - mae: 0.0150 - val_loss: 2.8745e-04 - val_mae: 0.0150
# Epoch 98/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.6545e-04 - mae: 0.0132 - val_loss: 1.6210e-04 - val_mae: 0.0111
# Epoch 99/100
# 25/25 [==============================] - 0s 5ms/step - loss: 1.1852e-04 - mae: 0.0088 - val_loss: 3.3968e-05 - val_mae: 0.0048
# Epoch 100/100
# 25/25 [==============================] - 0s 4ms/step - loss: 2.0640e-05 - mae: 0.0036 - val_loss: 6.2807e-06 - val_mae: 0.0020
# Elapsed Time =>  0:00:11.332645

# %%
plt.title('Loss Trend')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()
plt.legend(loc='best')

plt.show()

# %%
pred = model.predict(x_test)

print(pred.shape)
# Out:
# 7/7 [==============================] - 0s 2ms/step
# (196, 1)

# %%
rand_idx = np.random.randint(0, len(y_test), size=5)

print('random idx = ',rand_idx, '\n')

print('pred  = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])

rand_idx = np.random.randint(0, len(y_test), size=5)

print('\n\nrandom idx = ',rand_idx, '\n')

print('pred  = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])
# Out:
# random idx =  [ 30 173  56 195  32]
#
# pred  =  [ 0.5023106   0.13649449 -0.20100269 -1.4250106   0.24953887]
# label =  [ 0.50731935  0.13633806 -0.20078373 -1.42698617  0.25367797]
#
#
# random idx =  [ 54 125 146 114  45]
#
# pred  =  [-0.00653212  0.56570417  1.4231395   0.8333879   0.03876198]
# label =  [-0.00556474  0.56570501  1.42900005  0.83162584  0.03820471]

# %%
plt.plot(pred, label='prediction')
plt.plot(y_test, label='label')
plt.grid()
plt.legend(loc='best')

plt.show()
